# %%
def ones(n):
    if n == 0:
        print(1)
    else:
        for i in range(2**n):
            ones(n-1)
  
print(ones(2))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# None

# %%
def merge_sort(a):
    med = len(a)//2
    l = a[:med]
    r = a[med:]
    print("la partie gauche vaut :", l)
    print("la partie droite vaut :", r)
    merge_sort(l)
    merge_sort(r)
    i = j = k = 0
    while i < len(l) and j < len(r):
        if l[i] < r[j]:
            a[k] = l[i]
            i += 1
        else:
            a[k] = r[j]
            j += 1
        k += 1

    # Checking if any element was left
    while i < len(l):
        r[k] = l[i]
        i += 1
        k += 1

    while j < len(r):
        a[k] = r[j]
        j += 1
        k += 1
def printList(a):
    for i in range(len(a)):
        print(a[i], end=" ")
    print()
    
a = [5,45,2,4,58,6,4]     
merge_sort(a)
# Out:
# la partie gauche vaut : [5, 45, 2]
# la partie droite vaut : [4, 58, 6, 4]
# la partie gauche vaut : [5]
# la partie droite vaut : [45, 2]
# la partie gauche vaut : []
# la partie droite vaut : [5]
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# la partie droite vaut : []
# la partie gauche vaut : []
# ...
